# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.6/756.6 kB 7.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
from ultralytics import YOLO
model=YOLO()
model.train(data="/content/drive/MyDrive/Phone Detect.yolov8/data.yaml",epochs=1)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 23.6MB/s]
# Ultralytics YOLOv8.2.14 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
 from ultralytics import YOLO
# !yolo task=detect mode=val model="/content/runs/detect/train/weights/best.pt" data ="/content/drive/MyDrive/Phone Detect.yolov8/data.yaml"
# Out:
# Ultralytics YOLOv8.2.14 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Phone Detect.yolov8/valid/labels.cache... 1483 images, 0 backgrounds, 0 corrupt: 100% 1483/1483 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 93/93 [08:25<00:00,  5.43s/it]
#                    all       1483       2126      0.659      0.607      0.631      0.396
# Speed: 8.3ms preprocess, 301.4ms inference, 0.0ms loss, 4.2ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/best.pt" conf =0.14 source ="/content/drive/MyDrive/Phone Detect.yolov8/test/images"
# Out:
# Ultralytics YOLOv8.2.14 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/358 /content/drive/MyDrive/Phone Detect.yolov8/test/images/00115506f32aa051_jpg.rf.6bb4e9760324da8495342ee33d82f094.jpg: 640x640 4 0s, 376.1ms
# image 2/358 /content/drive/MyDrive/Phone Detect.yolov8/test/images/00209998b801428e_jpg.rf.4f3820a7125626e1ee89f8c265c28108.jpg: 640x640 8 0s, 224.5ms
# image 3/358 /content/drive/MyDrive/Phone Detect.yolov8/test/images/0033d09deafc7bcd_jpg.rf.27e7d8b4a657701818fc9787509886b5.jpg: 640x640 1 0, 198.7ms
# image 4/358 /content/drive/MyDrive/Phone Detect.yolov8/test/images/005cb9e795fa91de_jpg.rf.009850f1f972ddd21fc662d37bb052f1.jpg: 640x640 5 0s, 351.9ms
# image 5/358 /content/drive/MyDrive/Phone Detect.yolov8/test/images/008780d91774e5f1_jpg.rf.f01c002c4e6038d1fb12a2c825709d58.jpg: 640x640 4 0s, 203.0ms
# ...
